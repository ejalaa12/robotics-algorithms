# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Linear Regression (1D)
# Let's start with linear regression
# a simple problem
# which means finds the best linear equation that fits to noisy points.
#
# so we have $ (x_i, y_i) $ points, that we assume will fit a linear line $a x + b$

# %%
# let's generate a random line
N = 1000
a, b = np.random.uniform(0, 10, 2)

def linear_fun(x, a=a, b=b):
    return a * x + b

x = np.linspace(-50, 50, N)
ideal_line = linear_fun(x)

# %%
# and points that should lie on that line
# 3.0 is the std of the noisy points
points = ideal_line + 3.0 * np.random.randn(N)

# %%
# let's plot that
plt.scatter(x, points, marker='+', color='grey', alpha=0.8)
plt.plot(x, ideal_line, 'k-', label=f'original: {a:.2f}x+{b:.2f}')
plt.legend()

# %%
# now let's try to fit a curve to the points
# of course we can use already existing methods:
import scipy.stats as stats
res = stats.linregress(x, points)

# %%
# let's plot that
plt.scatter(x, points, marker='+', color='grey', alpha=0.8)
plt.plot(x, ideal_line, 'k-', label=f'original: {a:.2f}x+{b:.2f}')
plt.plot(x, linear_fun(x, res.slope, res.intercept), 'g--', label=f'scipy.linregress: {res.slope:.2f}x+{res.intercept:.2f}')
plt.legend()

# %% [markdown]
# ## Remarks
# Notice how this works well, but does not find the exact initial values.
# Particularly the intercept...
#
# if we increase N from 100 -> 1000?
# >  we don't necessarily get a better result.
#
# Maybe because we don't have values around those points ?
# > Yes !! that worked by generating points between -50, 50 instead of [0,100]

# %% [markdown]
# ## now let's do this "manually"
#
# we're going to use gradient descent.
# For that we need a cost function
#
# ### Cost function
#
# The simplest cost function we can think of is the sum of all errors
#
# $$
# J(a, b) = \sum_{i=1}^{N}r_i
# $$
#
# Where $r_i$ is the error function
# $$
# r_i = a x_i + b - y_i
# $$
#
# But summing the errors only is problematic because of the sign (imagine half the errors are negative and the other half is positive, then the sum is 0.... ).
# So we sum the square errors, and then a trick is to divide by two (practical for derivatives)
# $$
# J(a, b) = \frac{1}{2} \sum_{i=1}^{N}r_i^2
# $$

# %%
def errors(xi, yi, a, b):
    return np.square(linear_fun(xi, a, b) - yi)

def cost(xi, yi, a, b):
    return 0.5 * np.sum(np.square(errors(xi, yi, a, b)))

# %% [markdown]
# ### Jacobians
#
# Gradient descent means we need to compute the derivative of the cost function relative to all variables, in our case $a$ and $b$
#
# $$
# \frac{\partial J(a,b)}{\partial a} = \sum_{i=1}^{N}{r_i x_i}
# $$
#
# $$
# \frac{\partial J(a,b)}{\partial b} = \sum_{i=1}^{N}{r_i}
# $$

# %%
def jacob(xi, yi, a, b):
    e = errors(xi, yi, a, b)
    dJda = e @ xi
    dJdb = np.sum(e)
    return dJda, dJdb

# %% [markdown]
# ### Algorithm
#
# Now that we have computed the gradient, we need a step by step instructions to apply the gradient descent.

# %%
# First we need a first guess for a and b
a_guess, b_guess = 1, 0

# Then let's compute what the function would be if we used those guess
guess_0 = linear_fun(x, a_guess, b_guess)

# %%
plt.plot(x, guess_0, label='guess0')
plt.scatter(x, points, marker='+', color='grey', alpha=0.8)
plt.plot(x, ideal_line, 'k-', label=f'original: {a:.2f}x+{b:.2f}')
plt.legend()

# %%
# This is not a good guess, but let's compute the cost to see how much
cost(x, points, a_guess, b_guess)
# Out:
# np.float64(5345941131.471762)

# %%
# let's see what the jacobians tells us
jacob(x, points, a_guess, b_guess)
# Out:
# (np.float64(9842741.324652009), np.float64(2426779.2512559146))

# %%
# We can update the guesses for a and b with those jacobians
# enter gradient descent update part!
# we need and alpha (learning rate)
alpha = 1e-10

dJda, dJdb = jacob(x, points, a_guess, b_guess)
a_1 = a_guess - alpha * dJda
b_1 = b_guess - alpha * dJdb

# what's the new cost?
cost(x, points, a_1, b_1)
# Out:
# np.float64(5358190861.107014)

# %%
a_1, b_1
# Out:
# (np.float64(0.9990157258675348), np.float64(-0.00024267792512559146))

# %%
# Note, we see that choosing a relatively big alpha will drastically change a and b
# let's test the algorithm anyway
a_g = a_guess
b_g = b_guess
a_guesses = [a_g]
b_guesses = [b_g]
costs = [cost(x, points, a_g, b_g)]

alpha = 0.00000001

for i in range(100):
    dJda, dJdb = jacob(x, points, a_g, b_g)
    a_g = a_g - alpha * dJda
    b_g = b_g - alpha * dJdb
    a_guesses.append(a_g)
    b_guesses.append(b_g)
    costs.append(cost(x, points, a_g, b_g))

fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
ax1.plot(a_guesses)
ax2.plot(b_guesses)
ax3.plot(costs)
# Out:
# /tmp/ipykernel_11559/536070724.py:4: RuntimeWarning: overflow encountered in square
#   return 0.5 * np.sum(np.square(errors(xi, yi, a, b)))
# /tmp/ipykernel_11559/536070724.py:2: RuntimeWarning: overflow encountered in square
#   return np.square(linear_fun(xi, a, b) - yi)
# /tmp/ipykernel_11559/1394661996.py:3: RuntimeWarning: invalid value encountered in matmul
#   dJda = e @ xi

# %%
costs
# Out:
# [np.float64(5345941131.471762),
#  np.float64(6679518536.957432),
#  np.float64(8360983358.218128),
#  np.float64(10486412238.426964),
#  np.float64(13180476275.734985),
#  np.float64(16605789103.69656),
#  np.float64(20975664257.787537),
#  np.float64(26571680807.60859),
#  np.float64(33768103323.97287),
#  np.float64(43066186041.78151),
#  np.float64(55142908045.68906),
#  np.float64(70921061116.29782),
#  np.float64(91671390717.49818),
#  np.float64(119163610151.18689),
#  np.float64(155893208117.92505),
#  np.float64(205427987236.1368),
#  np.float64(272947592837.23608),
#  np.float64(366101066934.4538),
#  np.float64(496401374292.9309),
#  np.float64(681551299696.4877),
#  np.float64(949433807153.6139),
#  np.float64(1345177990834.972),
#  np.float64(1944125553480.642),
#  np.float64(2876609110812.04),
#  np.float64(4377551326154.005),
#  np.float64(6891219288231.236),
#  np.float64(11306779365235.645),
#  np.float64(19528762077533.516),
#  np.float64(35987406379906.66),
#  np.float64(72098248994773.95),
#  np.float64(161356408726412.44),
#  np.float64(420251018697519.2),
#  np.float64(1359296821569785.0),
#  np.float64(6094767808464765.0),
#  np.float64(4.631725313596981e+16),
#  np.float64(8.918635846633219e+17),
#  np.float64(1.0479540357119499e+20),
#  np.float64(5.593673143945707e+23),
#  np.float64(1.0302797056210038e+31),
#  np.float64(3.2898491370408944e+45),
#  np.float64(3.351122024639256e+74),
#  np.float64(3.477243747250698e+132),
#  np.float64(3.7437640402220544e+248),
#  np.float64(inf),
#  np.float64(inf),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan),
#  np.float64(nan)]
